# %% [markdown]
# # **LAB 1 - PART 1**
# Data exploration, cleaning and preprocessing

# %% [markdown]
# ### Import tools

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler,StandardScaler,LabelEncoder

# %% [markdown]
# ## **1. Data Exploration**
# Read the Data_example.csv files
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - `pd.read_csv()`
#
#
# <details>
# <summary>
# <font size="3" color="green">
# <b>more hints</b>
# </summary>
# </font>
#
# How was the file encoded?🤔
# </details>
# </details>

# %%
### START CODE HERE ###

df = pd.read_csv("./Data_example.csv", encoding='ISO-8859-1')
# Latin1 encoding### END CODE HERE ###

# %% [markdown]
# Visulize the dataframe in cell below.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output
# </font>
# </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
df
### END CODE HERE ###
# Out:
#        X     Y              Z
# 0     19  1927            cat
# 1    NaN  2300            dog
# 2     15   NaN           bird
# 3     16  5959            cat
# 4     16    AB            cat
# 5    NaN  4594            dog
# 6     19  1927            cat
# 7     20  2879  birdï¿½ï¿½ï¿½
# 8     21   NaN            NaN
# 9      0  4096            cat
# 10     A  6730            cat
# 11    25     0           bird
# 12     0  2792            dog
# 13    33  2575      dogï¿½ï¿½
# 14  1000  4959           bird
# 15    19  1927            cat
# 16    36  4580            dog
# 17    40  5869            NaN
# 18   NaN  4178            dog
# 19    45   NaN            cat

# %% [markdown]
# View the data frame information
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# -  `.info()`
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       20 non-null     Int64
#  1   Y       20 non-null     float64
#  2   Z       20 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 628.0 bytes
# ```
#
# </details>

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     object
#  1   Y       17 non-null     object
#  2   Z       18 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes
# None

# %% [markdown]
# ## **2. Data Cleaning**

# %% [markdown]
# ### Replace
# Use the `replace()` method to remove non-ASCII characters from specific columns in the DataFrame. Then visualize the DataFrame.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Use regular expression.
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
df['Z'] = df['Z'].str.replace('[^\x00-\x7F]+', '', regex=True)
### END CODE HERE ###
df
# Out:
#        X     Y     Z
# 0     19  1927   cat
# 1    NaN  2300   dog
# 2     15   NaN  bird
# 3     16  5959   cat
# 4     16    AB   cat
# 5    NaN  4594   dog
# 6     19  1927   cat
# 7     20  2879  bird
# 8     21   NaN   NaN
# 9      0  4096   cat
# 10     A  6730   cat
# 11    25     0  bird
# 12     0  2792   dog
# 13    33  2575   dog
# 14  1000  4959  bird
# 15    19  1927   cat
# 16    36  4580   dog
# 17    40  5869   NaN
# 18   NaN  4178   dog
# 19    45   NaN   cat

# %% [markdown]
# ### Convert Data Types
# Converting the data types of specific columns in a pandas DataFrame.
#
# | Column | Data Type |
# | ------ | --------- |
# | X      | int64     |
# | Y      | float64   |
# | Z      | string    |
#
# </br>
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - `pd.to_numeric()` and `.astype()` might be useful here.
# </details>

# %%
### START CODE HERE ###
# Converting data types
df['X'] = pd.to_numeric(df['X'], errors='coerce').astype('Int64')  # Convert to integer, handle non-numeric values
df['Y'] = pd.to_numeric(df['Y'], errors='coerce')  # Convert to float, handle non-numeric values
df['Z'] = df['Z'].astype("string")  # Convert to string
print(df)

### END CODE HERE ###
# Out:
#        X       Y     Z
# 0     19  1927.0   cat
# 1   <NA>  2300.0   dog
# 2     15     NaN  bird
# 3     16  5959.0   cat
# 4     16     NaN   cat
# 5   <NA>  4594.0   dog
# 6     19  1927.0   cat
# 7     20  2879.0  bird
# 8     21     NaN  <NA>
# 9      0  4096.0   cat
# 10  <NA>  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 15    19  1927.0   cat
# 16    36  4580.0   dog
# 17    40  5869.0  <NA>
# 18  <NA>  4178.0   dog
# 19    45     NaN   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       16 non-null     Int64
#  1   Y       16 non-null     float64
#  2   Z       18 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 628.0 bytes
#
# ```
#
# </details>

# %%
print(df.info())
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       16 non-null     Int64
#  1   Y       16 non-null     float64
#  2   Z       18 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 632.0 bytes
# None
#        X       Y     Z
# 0     19  1927.0   cat
# 1   <NA>  2300.0   dog
# 2     15     NaN  bird
# 3     16  5959.0   cat
# 4     16     NaN   cat
# 5   <NA>  4594.0   dog
# 6     19  1927.0   cat
# 7     20  2879.0  bird
# 8     21     NaN  <NA>
# 9      0  4096.0   cat
# 10  <NA>  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 15    19  1927.0   cat
# 16    36  4580.0   dog
# 17    40  5869.0  <NA>
# 18  <NA>  4178.0   dog
# 19    45     NaN   cat

# %% [markdown]
# ### Drop the duplicates
# Drop the duplicates rows using
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - `.drop_duplicates(inplace=True)`
# </details>

# %%
### START CODE HERE ###
df = df.drop_duplicates()
### END CODE HERE ###

# %% [markdown]
# The `df.describe()` output includes the following statistics for each column:
# - count: Number of non-null values
# - mean: Mean (average) value
# - std: Standard deviation, which measures the amount of variation or dispersion
# - min: Minimum value
# - 25%: First quartile (25th percentile)
# - 50%: Median (50th percentile)
# - 75%: Third quartile (75th percentile)
# - max: Maximum value
#
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# </br>
#
# |       |      X |          Y |
# |-------|--------|------------|
# | count | 14.0   | 14.00000   |
# | mean  | 91.857 | 3817.00000 |
# | std   | 261.717| 1837.61074 |
# | min   | 0.0    | 0.00000    |
# | 25%   | 16.0   | 2629.25000 |
# | 50%   | 20.5   | 4137.00000 |
# | 75%   | 35.25  | 4867.75000 |
# | max   | 1000.0 | 6730.00000 |
#
#
# </details>

# %%
df.describe()
# Out:
#                 X           Y
# count        14.0    14.00000
# mean    91.857143  3817.00000
# std    261.717069  1837.61074
# min           0.0     0.00000
# 25%          16.0  2629.25000
# 50%          20.5  4137.00000
# 75%         35.25  4867.75000
# max        1000.0  6730.00000

# %% [markdown]
# ### Drop NAN

# %% [markdown]
# The `df.dropna()` method will return a new DataFrame with rows that do not contain any missing values. It removes any row where at least one element is missing. By default, this operation is performed on all columns. </br></br>
# In the cell below, you will drop rows that have ***2 NaN values***.

# %%
### START CODE HERE ###
df = df.dropna(thresh=2)          #FIX
### END CODE HERE ###
df
# Out:
#        X       Y     Z
# 0     19  1927.0   cat
# 1   <NA>  2300.0   dog
# 2     15     NaN  bird
# 3     16  5959.0   cat
# 4     16     NaN   cat
# 5   <NA>  4594.0   dog
# 7     20  2879.0  bird
# 9      0  4096.0   cat
# 10  <NA>  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 16    36  4580.0   dog
# 17    40  5869.0  <NA>
# 18  <NA>  4178.0   dog
# 19    45     NaN   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       13 non-null     Int64
#  1   Y       14 non-null     float64
#  2   Z       16 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes
#
# ```
#
# </details>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       13 non-null     Int64
#  1   Y       14 non-null     float64
#  2   Z       16 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes

# %% [markdown]
# ### Fill NA
# Before proceeding with filling missing values, it is crucial to comprehend the significance of each numerical column in the dataset. This understanding will guide the appropriate method for handling missing data in a way that aligns with the context and characteristics of each column.

# %% [markdown]
# Replace the NA with specific values or conditions.
#
# | Column | Condition |
# | ------ | --------- |
# | X      | mean or median    |
# | Y      | mean or median    |
# | Z      | previous row    |

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Please explore the statistical values for each column (mean, median, min, max, etc.).
# - `.fillna()`
# </details>

# %%
### START CODE HERE ###
df['X'].fillna(value=int(df['X'].median()),inplace=True)
# 1000 ดึง mean สูง ใช้ median แทน

df['Y'].fillna(value=df['Y'].mean(),inplace=True)
#df['Z'] = df['Z'].replace('nan',np.nan)
df['Z'].fillna(method='bfill' ,inplace=True)


### END CODE HERE ###
df
# Out:
#        X       Y     Z
# 0     19  1927.0   cat
# 1     20  2300.0   dog
# 2     15  3817.0  bird
# 3     16  5959.0   cat
# 4     16  3817.0   cat
# 5     20  4594.0   dog
# 7     20  2879.0  bird
# 9      0  4096.0   cat
# 10    20  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 16    36  4580.0   dog
# 17    40  5869.0   dog
# 18    20  4178.0   dog
# 19    45  3817.0   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     Int64
#  1   Y       17 non-null     float64
#  2   Z       17 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes
#
# ```
#
# </details>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     Int64
#  1   Y       17 non-null     float64
#  2   Z       17 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes

# %% [markdown]
# <font size="3" color="Red">
# <b>Which fill NA method have you selected, and why? </br>Please explain in the cell below.</b>
# </font>

# %%
"""
X : ค่า 1000 ดึง mean สูง ใช้ median แทน
Y : mean เพราะ 
"""
# Out:
# '\nX : ค่า 1000 ดึง mean สูง ใช้ median แทน\nY : mean เพราะ \n'

# %% [markdown]
# ## **3. Data Transform**
# **NOTE** : This section will demonstrate the difference between Min-Max scaling and Standard scaling before and after removing outliers.

# %% [markdown]
# Show the boxplot of original dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
sns.boxplot(df)


### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# ### Min-Max Scaling
#
# Scaling columns X and Y using Min-Max scaling and placing the results in new columns of `tmpmm_df`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
def scale(data,scaler):
    tmp = data.loc[:,["X","Y"]]
    tmp = pd.DataFrame(scaler.fit_transform(tmp), columns=tmp.columns,index=data.index) #Iindex is needed!
    tmp['Z'] = df['Z']
    return tmp

### START CODE HERE ###
tmpmm_df = scale(df,  MinMaxScaler())
### END CODE HERE ###
tmpmm_df
# Out:
#         X         Y     Z
# 0   0.019  0.286330   cat
# 1   0.020  0.341753   dog
# 2   0.015  0.567162  bird
# 3   0.016  0.885438   cat
# 4   0.016  0.567162   cat
# 5   0.020  0.682615   dog
# 7   0.020  0.427786  bird
# 9   0.000  0.608618   cat
# 10  0.020  1.000000   cat
# 11  0.025  0.000000  bird
# 12  0.000  0.414859   dog
# 13  0.033  0.382615   dog
# 14  1.000  0.736850  bird
# 16  0.036  0.680535   dog
# 17  0.040  0.872065   dog
# 18  0.020  0.620802   dog
# 19  0.045  0.567162   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_minmax     | Y_minmax     |
# |---------|--------------|--------------|--------------|--------------|
# | count   | 17.0         | 17.000000    | 17.000000    | 17.000000    |
# | mean    | 79.117647    | 3817.000000  | 0.079118     | 0.567162     |
# | std     | 237.607839   | 1656.399937  | 0.237608     | 0.246122     |
# | min     | 0.0          | 0.000000     | 0.000000     | 0.000000     |
# | 25%     | 16.0         | 2792.000000  | 0.016000     | 0.414859     |
# | 50%     | 20.0         | 3817.000000  | 0.020000     | 0.567162     |
# | 75%     | 33.0         | 4594.000000  | 0.033000     | 0.682615     |
# | max     | 1000.0       | 6730.000000  | 1.000000     | 1.000000     |
#
# </details>

# %%
tmpmm_df.describe()
# Out:
#                X          Y
# count  17.000000  17.000000
# mean    0.079118   0.567162
# std     0.237608   0.246122
# min     0.000000   0.000000
# 25%     0.016000   0.414859
# 50%     0.020000   0.567162
# 75%     0.033000   0.682615
# max     1.000000   1.000000

# %% [markdown]
# Show the boxplot of Min-Max scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
sns.boxplot(tmpmm_df)


### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# #### Remove outliers
# Remove outliers from the DataFrame `tmpmm_df2` based on the boxplot method. The Interquartile Range (IQR) is used to define the range within which data points are considered normal, and points outside this range are treated as potential outliers.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# 1. Calculating Quartiles and IQR:
#
# >- $Q_{1_X}, Q_{3_X}, IQR_X$ : Calculate the first quartile, third quartile, and IQR for column 'X'.
# >- $Q_{1_Y}, Q_{3_Y}, IQR_Y$ : Calculate the first quartile, third quartile, and IQR for column 'Y'.
# 2. Defining Lower and Upper Bounds:
#
# >- lower_bound_X, upper_bound_X: Define the lower and upper bounds for column 'X' using the $1.5 * IQR$ rule.
# >- lower_bound_Y, upper_bound_Y: Define the lower and upper bounds for column 'Y' using the $1.5 * IQR$ rule.
# 3. Creating Outlier Mask:
#
# >- outlier_mask: Create a boolean mask to identify rows containing outliers. Rows where values fall outside the defined bounds for either 'X' or 'Y' are marked as outliers.
# 4. Removing Outliers:
# >- Update `tmpmm_df2` by keeping only the rows where the values are not marked as outliers according to the mask.
# </details>

# %%
def removeOutlier(data):
    Q1_X = data['X'].quantile(0.25)
    Q3_X = data['X'].quantile(0.75)
    IQR_X = Q3_X - Q1_X
    Q1_Y = data['Y'].quantile(0.25)
    Q3_Y = data['Y'].quantile(0.75)
    IQR_Y = Q3_Y - Q1_Y

    # mean_X = data['X'].mean()
    # mean_Y = data['Y'].mean()
    # std_X = data['X'].std()
    # std_Y = data['Y'].std()

    lower_bound_X = Q1_X - 1.5 * IQR_X
    upper_bound_X = Q1_X + 1.5 * IQR_X

    lower_bound_Y = Q1_Y - 1.5 * IQR_Y
    upper_bound_Y = Q1_Y + 1.5 * IQR_Y

    return data[(data['X'] >= lower_bound_X) & (data['X'] <= upper_bound_X) & (data['Y'] >= lower_bound_Y) & (data['Y'] <= upper_bound_Y)]


tmpmm_df2 = removeOutlier( tmpmm_df.copy())

### END CODE HERE ###
tmpmm_df2
# Out:
#         X         Y     Z
# 0   0.019  0.286330   cat
# 1   0.020  0.341753   dog
# 2   0.015  0.567162  bird
# 4   0.016  0.567162   cat
# 5   0.020  0.682615   dog
# 7   0.020  0.427786  bird
# 9   0.000  0.608618   cat
# 12  0.000  0.414859   dog
# 13  0.033  0.382615   dog
# 16  0.036  0.680535   dog
# 18  0.020  0.620802   dog

# %% [markdown]
# After removing outliers, scale columns X and Y using Min-Max scaling, and place the results in new columns of `tmpmm_df2`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
### START CODE HERE ###
minmax_scaler = MinMaxScaler()
tmpmm_df2 = scale(tmpmm_df2, minmax_scaler)
### END CODE HERE ###
tmpmm_df2
# Out:
#            X         Y     Z
# 0   0.527778  0.000000   cat
# 1   0.555556  0.139858   dog
# 2   0.416667  0.708661  bird
# 4   0.444444  0.708661   cat
# 5   0.555556  1.000000   dog
# 7   0.555556  0.356955  bird
# 9   0.000000  0.813273   cat
# 12  0.000000  0.324334   dog
# 13  0.916667  0.242970   dog
# 16  1.000000  0.994751   dog
# 18  0.555556  0.844019   dog

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_minmax     | Y_minmax     |
# |---------|--------------|--------------|--------------|--------------|
# | count   | 15.0         | 15.000000    | 15.000000    | 15.000000    |
# | mean    | 21.333333    | 3995.333333  | 0.474074     | 0.430634     |
# | std     | 12.76528     | 1402.749273  | 0.283673     | 0.292057     |
# | min     | 0.0          | 1927.000000  | 0.000000     | 0.000000     |
# | 25%     | 16.0         | 2835.500000  | 0.355556     | 0.189153     |
# | 50%     | 20.0         | 3817.000000  | 0.444444     | 0.393504     |
# | 75%     | 26.5         | 4587.000000  | 0.588889     | 0.553821     |
# | max     | 45.0         | 6730.000000  | 1.000000     | 1.000000     |
# </details>

# %%
tmpmm_df2.describe()
# Out:
#                X          Y
# count  11.000000  11.000000
# mean    0.502525   0.557589
# std     0.307683   0.354817
# min     0.000000   0.000000
# 25%     0.430556   0.283652
# 50%     0.555556   0.708661
# 75%     0.555556   0.828646
# max     1.000000   1.000000

# %% [markdown]
# Show the removed outliers boxplot of Min-Max scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
#
# ![image.png](attachment:image.png)
# </details>

# %%
### START CODE HERE ###
sns.boxplot(data=tmpmm_df2)

### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# ### Standardize Scaling
#
# Scaling columns X and Y using Standardize scaling and placing the results in new columns of `tmpstd_df`.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
### START CODE HERE ###
standardize_scaler = StandardScaler()

tmpstd_df = scale(df.copy() , standardize_scaler)
### END CODE HERE ###
tmpstd_df
# Out:
#            X         Y     Z
# 0  -0.260799 -1.176146   cat
# 1  -0.256461 -0.944028   dog
# 2  -0.278151  0.000000  bird
# 3  -0.273813  1.332965   cat
# 4  -0.273813  0.000000   cat
# 5  -0.256461  0.483527   dog
# 7  -0.256461 -0.583717  bird
# 9  -0.343224  0.173621   cat
# 10 -0.256461  1.812758   cat
# 11 -0.234770 -2.375316  bird
# 12 -0.343224 -0.637857   dog
# 13 -0.200065 -0.772896   dog
# 14  3.994918  0.710666  bird
# 16 -0.187050  0.474814   dog
# 17 -0.169698  1.276958   dog
# 18 -0.256461  0.224650   dog
# 19 -0.148007  0.000000   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_standardize   | Y_standardize  |
# |---------|--------------|--------------|-----------------|-----------------|
# | count   | 17.0         | 17.000000    | 1.700000e+01    | 17.000000      |
# | mean    | 79.117647    | 3817.000000  | -2.612289e-17   | 0.000000       |
# | std     | 237.607839   | 1656.399937  | 1.030776e+00    | 1.030776       |
# | min     | 0.0          | 0.000000     | -3.432235e-01   | -2.375316      |
# | 25%     | 16.0         | 2792.000000  | -2.738133e-01   | -0.637857      |
# | 50%     | 20.0         | 3817.000000  | -2.564607e-01   | 0.000000       |
# | 75%     | 33.0         | 4594.000000  | -2.000649e-01   | 0.483527       |
# | max     | 1000.0       | 6730.000000  | 3.994918e+00    | 1.812758       |
#
# </details>

# %%
tmpstd_df.describe()
# Out:
#                   X          Y
# count  1.700000e+01  17.000000
# mean  -2.612289e-17   0.000000
# std    1.030776e+00   1.030776
# min   -3.432235e-01  -2.375316
# 25%   -2.738133e-01  -0.637857
# 50%   -2.564607e-01   0.000000
# 75%   -2.000649e-01   0.483527
# max    3.994918e+00   1.812758

# %% [markdown]
# Show the removed outliers boxplot of Min-Max scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# ![image.png](attachment:image.png)
# </details>

# %%
### START CODE HERE ###
sns.boxplot(data=tmpstd_df)
### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# #### Remove outliers
# from the DataFrame `tmpstd_df2` based on the boxplot method. The Interquartile Range (IQR) is used to define the range within which data points are considered normal, and points outside this range are treated as potential outliers.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Similar with the previous.
# </details>

# %%
tmpstd_df2 = removeOutlier(tmpstd_df.copy())

tmpstd_df2
# Out:
#            X         Y     Z
# 0  -0.260799 -1.176146   cat
# 1  -0.256461 -0.944028   dog
# 2  -0.278151  0.000000  bird
# 4  -0.273813  0.000000   cat
# 5  -0.256461  0.483527   dog
# 7  -0.256461 -0.583717  bird
# 9  -0.343224  0.173621   cat
# 12 -0.343224 -0.637857   dog
# 13 -0.200065 -0.772896   dog
# 16 -0.187050  0.474814   dog
# 18 -0.256461  0.224650   dog

# %% [markdown]
# After removing outliers, scale columns X and Y using Standardize scaling, and place the results in new columns of `tmpstd_df2`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
### START CODE HERE ###
standardize_scaler = StandardScaler()
tmpstd_df2 = scale(tmpmm_df2, standardize_scaler)

### END CODE HERE ###
tmpstd_df2
# Out:
#            X         Y     Z
# 0   0.086079 -1.648186   cat
# 1   0.180766 -1.234779   dog
# 2  -0.292669  0.446556  bird
# 4  -0.197982  0.446556   cat
# 5   0.180766  1.307727   dog
# 7   0.180766 -0.593057  bird
# 9  -1.712973  0.755780   cat
# 12 -1.712973 -0.689481   dog
# 13  1.411696 -0.929989   dog
# 16  1.695757  1.292211   dog
# 18  0.180766  0.846663   dog

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_standardize   | Y_standardize  |
# |---------|--------------|--------------|-----------------|-----------------|
# | count   | 15.0         | 15.000000    | 1.500000e+01    | 1.500000e+01    |
# | mean    | 21.333333    | 3995.333333  | 1.332268e-16   | -8.326673e-17  |
# | std     | 12.76528     | 1402.749273  | 1.035098e+00   | 1.035098e+00   |
# | min     | 0.0          | 1927.000000  | -1.729856e+00  | -1.526237e+00  |
# | 25%     | 16.0         | 2835.500000  | -4.324640e-01  | -8.558490e-01  |
# | 50%     | 20.0         | 3817.000000  | -1.081160e-01  | -1.315934e-01  |
# | 75%     | 26.5         | 4587.000000  | 4.189495e-01   | 4.365949e-01   |
# | max     | 45.0         | 6730.000000  | 1.919059e+00   | 2.017929e+00   |
#
# </details>

# %%
tmpstd_df2.describe()
# Out:
#                   X             Y
# count  1.100000e+01  1.100000e+01
# mean  -2.523234e-18  7.065056e-17
# std    1.048809e+00  1.048809e+00
# min   -1.712973e+00 -1.648186e+00
# 25%   -2.453253e-01 -8.097350e-01
# 50%    1.807660e-01  4.465558e-01
# 75%    1.807660e-01  8.012211e-01
# max    1.695757e+00  1.307727e+00

# %% [markdown]
# Show the removed outliers boxplot of Standardize scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# ![image.png](attachment:image.png)
# </details>

# %%
### START CODE HERE ###
sns.boxplot(data=tmpstd_df2)

### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# ## **4. Data Category Label**

# %% [markdown]
# **NOTE** : Please select one of the Scaling type from the previous section.

# %%
### START CODE HERE ###
standardize_scaler = StandardScaler()
superdf = removeOutlier(df.copy())
superdf = scale(superdf, standardize_scaler)

### END CODE HERE ###
superdf
# Out:
#            X         Y     Z
# 0   0.086079 -1.648186   cat
# 1   0.180766 -1.234779   dog
# 2  -0.292669  0.446556  bird
# 4  -0.197982  0.446556   cat
# 5   0.180766  1.307727   dog
# 7   0.180766 -0.593057  bird
# 9  -1.712973  0.755780   cat
# 12 -1.712973 -0.689481   dog
# 13  1.411696 -0.929989   dog
# 16  1.695757  1.292211   dog
# 18  0.180766  0.846663   dog

# %%
sns.boxplot(data=superdf[['X', 'Y']])
plt.show()

# %% [markdown]
# Reset DataFrame index.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |   | X        | Y        | Z    |
# |---|----------|----------|------|
# | 0 | 0.422222 | 0.000000 | cat  |
# | 1 | 0.444444 | 0.077660 | dog  |
# | 2 | 0.333333 | 0.393504 | bird |
# | 3 | 0.355556 | 0.839475 | cat  |
# | 4 | 0.355556 | 0.393504 | cat  |
#
#
# </details>

# %%
### START CODE HERE ###
superdf.reset_index()
### END CODE HERE ###
superdf.head()
# Out:
#           X         Y     Z
# 0  0.086079 -1.648186   cat
# 1  0.180766 -1.234779   dog
# 2 -0.292669  0.446556  bird
# 4 -0.197982  0.446556   cat
# 5  0.180766  1.307727   dog

# %% [markdown]
# #### Label Encoding
# Label Encoding `Z` column, and place the results in new columns of `df`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |   | X        | Y        | Z    | Z_labelEn |
# |---|----------|----------|------|-----------|
# | 0 | 0.422222 | 0.000000 | cat  | 1         |
# | 1 | 0.444444 | 0.077660 | dog  | 2         |
# | 2 | 0.333333 | 0.393504 | bird | 0         |
# | 3 | 0.355556 | 0.839475 | cat  | 1         |
# | 4 | 0.355556 | 0.393504 | cat  | 1         |
#
#
# </details>

# %%
### START CODE HERE ###
label_En = LabelEncoder()
encoded = superdf.copy()
encoded["Z"] = label_En.fit_transform(encoded["Z"])
### END CODE HERE ###
encoded
# Out:
#            X         Y  Z
# 0   0.086079 -1.648186  1
# 1   0.180766 -1.234779  2
# 2  -0.292669  0.446556  0
# 4  -0.197982  0.446556  1
# 5   0.180766  1.307727  2
# 7   0.180766 -0.593057  0
# 9  -1.712973  0.755780  1
# 12 -1.712973 -0.689481  2
# 13  1.411696 -0.929989  2
# 16  1.695757  1.292211  2
# 18  0.180766  0.846663  2

# %% [markdown]
# #### One Hot Encoding
# One Hot Encoding `Z` column, and place the results in new columns of `df`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |   | X        | Y        | Z    | Z_labelEn | Z_bird | Z_cat | Z_dog |
# |---|----------|----------|------|-----------|--------|-------|-------|
# | 0 | 0.422222 | 0.000000 | cat  | 1         | 0.0    | 1.0   | 0.0   |
# | 1 | 0.444444 | 0.077660 | dog  | 2         | 0.0    | 0.0   | 1.0   |
# | 2 | 0.333333 | 0.393504 | bird | 0         | 1.0    | 0.0   | 0.0   |
# | 3 | 0.355556 | 0.839475 | cat  | 1         | 0.0    | 1.0   | 0.0   |
# | 4 | 0.355556 | 0.393504 | cat  | 1         | 0.0    | 1.0   | 0.0   |
#
# </details>

# %%
### START CODE HERE ###
oneHot_En =  pd.get_dummies(superdf['Z'])
lastdf = superdf.join(oneHot_En)


### END CODE HERE ###
lastdf.head()
# Out:
#           X         Y     Z   bird    cat    dog
# 0  0.086079 -1.648186   cat  False   True  False
# 1  0.180766 -1.234779   dog  False  False   True
# 2 -0.292669  0.446556  bird   True  False  False
# 4 -0.197982  0.446556   cat  False   True  False
# 5  0.180766  1.307727   dog  False  False   True

# %% [markdown]
# Visualize the final DataFrame.

# %%
lastdf
# Out:
#            X         Y     Z   bird    cat    dog
# 0   0.086079 -1.648186   cat  False   True  False
# 1   0.180766 -1.234779   dog  False  False   True
# 2  -0.292669  0.446556  bird   True  False  False
# 4  -0.197982  0.446556   cat  False   True  False
# 5   0.180766  1.307727   dog  False  False   True
# 7   0.180766 -0.593057  bird   True  False  False
# 9  -1.712973  0.755780   cat  False   True  False
# 12 -1.712973 -0.689481   dog  False  False   True
# 13  1.411696 -0.929989   dog  False  False   True
# 16  1.695757  1.292211   dog  False  False   True
# 18  0.180766  0.846663   dog  False  False   True
